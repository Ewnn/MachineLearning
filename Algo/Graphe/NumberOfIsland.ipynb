# %%
class Solution(object):    
    def numIslands(self, grid):
        m = len(grid)
        n = len(grid[0])
        count = 0

        def remove(i,j):
            if grid[i,j] == 1:
                grid[i,j] = 0
        
    def DFS(row, col):
