# %%
def reverseList(head):
    prev = None
    current = head

    while current is not None:
        next_node = current.next
        current.next = prev
        prev = current
        current = next_node
    return prev

reverseList(head = [1,2,3,4,5])

#Je ne suis pas sûr de l'avoir compris celui là
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 12
#       9         current = next_node
#      10     return prev
# ---> 12 reverseList(head = [1,2,3,4,5])
#
# Cell In[12], line 6, in reverseList(head)
#       3 current = head
#       5 while current is not None:
# ----> 6     next_node = current.next
#       7     current.next = prev
#       8     prev = current
#
# AttributeError: 'list' object has no attribute 'next'
